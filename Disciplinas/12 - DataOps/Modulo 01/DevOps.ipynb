# %%
from IPython.display import display, Image

# %% [markdown]
# # DevOps
#
# * DevOps é uma metodologia de desenvolvimento de software que traz entrega contínua para o ciclo de vida de desenvolvimento de sistemas, combinando equipes de desenvolvimento e equipes de operação em uma única unidade resposável por um produto ou serviço.

# %%
display(Image('Imagens/Imagem0001.png'))

# %% [markdown]
# ## Benefícios Devops
#
# * Velocidade
#
# * Entrega rápida
#
# * Confiabilidade
#
# * Escala
#
# * Equipes colaborativas
#
# * Segurança
#
# ## Ciclo de vida Devops
#
# * Código
#
# * Compilação
#
# * Testes Automatizados
#
# * Artefatos
#
# * Releases
#
# * Configuração
#
# * Monitoramento
#
# ## Práticas Devops
#
# * Integração Contínua
#
# * Entrega Contínua
#
# * Microsserviços
#
# * Infraestrutura como Código
#
# * Monitoramento
#
# * Equipe Colaborativa

# %% [markdown]
# ## Data Ops
#
# * "Capacidade de habilitar soluções, desenvolver produtos de dados e ativar dados para valor de negócios em todas as camadas de tecnologia, da infraestrutura à experiência". Michele Goetz, Vice-Presidente e Analista Principal da Forrester
#
# ## Principios DataOps
#
# * Satisfaçao Cliente
#
# * Análise do trabalho
#
# * Mudanças
#
# * Trabalho em equipe
#
# * Interação diária
#
# * Auto organizar
#
# * Reduza o Heroísmo
#
# * Reflita
#
# * Analytics é código
#
# * Orquestrar
#
# * Resultados descartáveis
#
# * Ambientes descartáveis
#
# * Simplicidade
#
# * Análise é fabricação
#
# * Qualidade é fundamental
#
# * Monitorar qualidade e desempenho
#
# * Reutilizar componentes
#
# * Otimizar tempo para implantação de soluções

# %%
display(Image('Imagens/Imagem0002.png'), Image('Imagens/Imagem0003.png'))

# %% [markdown]
# ## MLOps
#
# * MLOps (um composto de aprendizado de máquina e operações de tecnologia da informação) é uma nova disciplina/foco/prática para colaboração e comunicação entre cientista de dados e profissionais de técnicas da informação (TI) enquanto automatiza e produz algoritmos de aprendizado de máquina. Por meio da prática e das ferramentas, o MLOps visa estabelecer uma cultura e um ambiente onde as tecnologias de ML pode gerar beneficios ao construir, testar e lançar a tecnologia de ML de forma rapida, frequente e confiável.

# %%
display(Image('Imagens/Imagem0004.png'))

# %% [markdown]
# ## CD4ML - Continuos Delivery for Machine Learning
#
# * "A entrega contínua é a capacidade de colocar mudanças de todos os tipo - incluindo novos recursos, mudanças de configuração, correção de bugs e experimentos - em produção ou nas mãos dos usuários com segurança e rapidez de forma sustentável."

# %%
display(Image('Imagens/Imagem0005.png'), Image('Imagens/Imagem0006.png'))

# %% [markdown]
# ### Dados (Feature Store)
#
# * Reutilização
#
# * Flexibilidade
#
# * Disponibilidade
#
# * Qualidade
#
# ### Desenvolvimento
#
# #### MLFlow
#
# * Rastreamento
#
# * Projetos
#
# * Modelos
#
# * Registro de modelos
#
# #### SageMaler Studio
#
# * Paga
# * AWS
#
# #### Treinamento/Deploy (Kubeflow)
#
# * Framework código aberto
#
# * Automatizar fluxos de ML
#
# * Suporte vários frameworks ML
#
# * Utiliza container
#
# * Portabilidade
#
# O projeto Kubeflow é dedicado a tornar as implantações de fluxos de trabalho de aprendizado de maquina (ML) no Kubernetes simples, portáteis e escalonáveis. Nosso objetivo não é recriar outros serviços, mas fornecer uma maneira direta de implantar os melhores sistemas de código aberto para ML em diversas estruturas. Em qualquer lugar que você esteja executando o Kubernetes, deve ser capaz de executar o Kubeflow.
