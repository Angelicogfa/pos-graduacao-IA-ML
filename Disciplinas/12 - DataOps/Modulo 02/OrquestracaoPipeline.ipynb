# %%
from IPython.display import Image, display

# %% [markdown]
# # Orquestração de pipeline de dados
#
# ## Fluxo CD para Machine Learning

# %%
display(Image('Imagens/Imagem0001.png'))

# %% [markdown]
# ### Treinamento/Deploy (Kubeflow)
#
# * O projeto Kubeflow é dedicado a tornar as implatações de fluxos de trabalho de aprendizado de máquina (ML) no Kubernetes simples, portáteis e escalonáveis. Nosso objetivo não é recriar outros serviços, mas fornecer uma maneira direta de implantar os melhores sistemas de código aberto para ML em diversas infraestruturas. Em qualquer lugar que você esteja executando o Kubernetes, deve ser capaz de executar o Kubeflow.
#
# * Framework código aberto
#
# * Automatizar fluxos de ML
#
# * Suporta vários frameworks ML
#
# * Utiliza contâiner
#
# * Portabilidade
#
# * https://www.kubeflow.org/
#
# * https://www.kubeflow.org/docs/components/pipelines/pipelines-quickstart/

# %% [markdown]
# ## Airflow
#
# https://airflow.apache.org/
#
# Criação de um pipeline de dados
#
# * Aquisição de dados
#
# * Validação dos dados
#
#
# Escalavel, Dinâmico, Extensível, Elegante.

# %%
display(Image('Imagens/Imagem0002.png'))

# %% [markdown]
# ### Componentes do Airflow
#
# * Banco de dados de metadados: O Airflow usa um banco de dados SQL para armazenar metadados sobre os extremamente popular com Airflow. Bancos de dados alternativos compatíveis com Airflow incluem MySql.
#
# * Servidor da Web e Agendador: O servidor da web do Airflow e o Agendador são processos separados executados (nesse caso) na máquina local e interagem com o banco de dados mencionado acima.
#
# * O Executor: é mostrado separadamente acima, uma vez que é comumente discutido no Airflow e na documentação, mas na realidade NÃO é um processo separado, mas executado dentro do Scheduler.
#
# * O(s) worker(s): São processos separados que também interagem com os outros componentes das arquiteturas do airflow e o repositorio de metadados.
#
# * airflow.cfg: pe o arquivo de configuração do Airflow que é necessário pelo WebServer, Scheduler e Workers.
#
# * DAGs: referem-se aos arquivos DAGs que contém código Python, representando os pipelines de dados a serem executados pelo AirFlow. A localização desses arquivos é especificado no arquivo de configuração do Airflow, mas eles precisam estar acessíveis para o servidor web, o agendador e os trabalhadores.
#
# ### Caracteristicas
#
# * Python
#
# * Monitoramento
#
# * Integrações
#
# * Facilidade
#
# * Opensource
#
# ### Operadores
#
# * BashOperator: executa um comando bash
#
# * PythonOperator: chama uma função em python arbitrária
#
# * EmailOperator: envia um email
#
# * SimpleHttpOperator: envia uma solicção HTTP
