# %% [markdown]
# # Processo de machine learning
#
# ## Metodologia para descoberta de conhecimento em banco de dados
#
# * Técnicas de aprendizado supervisionado e não supervisionado
#
# * Regras de associação
#
# * Agrupamento (cluster)
#
# * Classificação
#
# * Rede neural
#
# * Agrupamentos com K-Means
#
# * Classificador Naive Bayes, Arvore de decisão e outros algoritmos
#
# "Machine learning is the stude of computer algorithms that improve automatically trhough experience" - Machine Learning: Tom Michell, McGraw Hill, 1997.

# %% [markdown]
# ## Dominio da IA

# %%
from IPython.display import Image
Image('domain ia.png')

# %% [markdown]
# Datascience lifecycle
#
# https://docs.microsoft.com/en-us/azure/machine-learning/team-data-science-process/lifecycle-data

# %%
Image('datascience_life_cicle.png')

# %% [markdown]
# * Business Understanding
#
#     * Processo na descoberta de conhecimento
#
#     * Entender qual pergunta responder e com base nisso verificar se você possui esses dados
#
#     * Verificar se existe dados associados ao problema que podem enriquecer os dados já existentes
#
#     * Ajustar a pergunta com base no refinamento e questionamentos efetuados
#
# * Adquisição de dados
#
#     * Entendimento dos dados
#
#     * Tratamento dos dados: Valores omissos; pre-processamento; limpesa dos dados
#
# * Modelagem
#
#     * Feature engineering
#
#         * Transformação de dados
#
#         * Seleção de atributos
#
#         * Composição/Criação de atributos
#
#         * Tratamento;
#
#         * Redução de resolução/variância
#
#         * Remoção de vies (baias)
#
#     * Model training
#
#         * Algoritmos
#
#         * Combinação de algoritmo (ensemble)
#
#         * Ajuste fino dos hiper-parâmetros
#
#         * Gerenciamento do modelo
#
#     * Avaliação do modelo
#
#         * Validação de overfit e underfit
#
#         * Taxas de acertos e erros do modelo
#
#         * Testes
#
# * Deployment
#
#     * Versionamento do modelo
#
#     * Disponibilização do modelo por webapis
#
#     * Controle e metricas em produção

# %% [markdown]
# ## Tipos de aprendizado
#
# Os tipos de aprendizado podem ser classificados em:
#
# * Supervisionado
#
# * Não Supervisionado
#
# * Semisupervisionado
#
# * Aprendizado por reforço
#
#
# ### Aprendizado Supervisionado
#
# Dado de treinamento possui rótulos conhecidos
#
# Cria modulos para fazer previsões e se autcorrige quando as previsões ruins até atingir um desempenho desejado.
#
# * Indução de regras
#
# * Regressão
#
# * Redes neurais multicamadas
#
# * Aprendizado baseado em instância
#
# * Métodos baseados em kernels
#
# ### Aprendizado não supervisionado
#
# Dado não é rotulado ou não possui resultado conhecido.
#
# Modelo deduz estruturas a partir da entrega.
#
# * Agrupamento ou clustering
#
# * Detecção de anomalias
#
# * Redes neurais geradoras adversárias
#
# ### Aprendizado semisupervisionado
#
# Mistura dados rotulados (poucos) e não rotulados (muitos).
#
# Existe uma previsão desejável, mas o modelo precisa organizar estruturas.
#
# * Métodos geradores
#
# * Separação de baixa densidade
#
# * Métodos baseados em grafos
#
# * Métodos heuristicos
#
# ### Aprendizado por reforço
#
# Agente computacional interage com um ambiente dinâmico para atingir um objetivo.
#
# Não possui dados rotulados, mas recebe feedback do ambiente.
#
# Medida de desempenho ou utilidade define se o agente está caminhando na direção correta, no espaço de soluções.
#
# * Métodos de Monte Carlo
#
# * Método de diferenças temporais.

# %% [markdown]
# ## Mineração de dados
#
# Descrição de dados:
#
# * Caracterização e comparação
#
# Associação:
#
# * Descobrimento de regras
#
# * Correlação para causalidade
#
# Classificacao e Previsão:
#
# * Classificação baseada em valores
#
# * Estimação de valores ou classes a partir de atributos
#
# Clusterização ou segmentação:
#
# * Agrupamento de dados por semelhança
#
# Analise de tendência e desvio em séries temporais:
#
# * Encontrar a caracterizar tendências, definir padrões ao longo do tempo, encontrar desvios de dados (controle de estoque).

# %% [markdown]
# ## Introdução de Hipótese e Viés Indutivo
#
# * Em aprendizagem de máquina (supervisionada), o objetivo é encontrar uma função que mapeia as entradas das saídas.
#
# * Agente deve aprender a função com base em alguns exemplos de entradas com valores das saídas correspondentes.
#
# ### Exemplo ou Instância
#
# * Formalmente, um exemplo é uma par ($x$, $f(x)$), onde:
#
#     * $x$ é a entrada
#
#     * $f(x)$ é a saída aplicada a $x$.
#
# ### Indução de Hipotese
#
# * Indução
#
#     * Dada uma coleção de exeplos ($x$, $f(x)$), indução é uma maneira de encontrar uma função $h$ que seja uma aproximação de $f$.
#
# * Hipótese
#
#     * A função $h$ é chamada de uma Hipótese
#
# * Generalização
#
#      * Capacidade de uma função hipótese prever corretamente exemplos ainda não vistos.
#
# ### Exemplo de indução
#
# * Conjunto de exemplos usado na indução é chamado de conjunto de treinamento
#
# * A função hipótese $h$ é consistente se ela concorda com  $f$ em todos os exemplos do conjunto de treinamento.

# %%
Image('inducao_hipotese1.png')

# %%
Image('inducao_hipotese2.png')

# %%
Image('inducao_hipotese3.png')

# %% [markdown]
# ### Navalha de Ockham (ou principio da pacimônia)
#
# * Maximizar a combinação de consistência e simplicidade
#
# * Ou seja, prefira a hipótese mais simples que seja consistente com os dados de treinamento
#
# ## Overfiting e Underfiting
#
# * Se uma hipótese tem alta capacidade de previsão dos dados de treinamento e baixa capacidade de generalização, provavelmente o modelo pode ter sofrido *overfiting*.
#
# * Se uma hipótese tem baixa capacidade de previsão, mesmo nos dados de treinamento, pode ter sofrido *Underfiting*.
#
# ## Viés Indutivo
#
# * Algoritmos possuem preferência quanto à representação dos dados e à geração de regras, que podem limitar a busca no espaço de hipóteses.

# %% [markdown]
# ## Introdução
#
# Apresentação das caracteristicas básicas.
#
# Baseado no livro: Andresas C Muller, Sharah Guido (2016) Introduction Machine Learning with Python: A guide for Data Science 1st Edition

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\Guilherme\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Guilherme\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
iris = load_iris()
X = iris['data']
y = iris['target']

# %% [markdown]
# ### Explorando dados
#
# Descrevendo os dados do dataset iris

# %%
print(f'\nCampos para dataset iris: {iris.keys()}')

print(f'\nParte da descrição do dataset iris: {iris["DESCR"][:471]}')

print(f'\nNomes das classes: {iris["target_names"]}')

print(f'\nNomes das features: {iris["feature_names"]}')
# Out:
# Campos para dataset iris: dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])
#
# Parte da descrição do dataset iris: .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iri
#
# Nomes das classes: ['setosa' 'versicolor' 'virginica']
#
# Nomes das features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# ### Divisão da base original em base de testes e base de treinamento

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size=0.7)

print(f'\nBase de treinamento {X_train.shape}')
print(f'\nBase de teste {X_test.shape}')
# Out:
# Base de treinamento (45, 4)
#
# Base de teste (105, 4)

# %% [markdown]
# ### Visualização de dados

# %%
df = pd.DataFrame(np.c_[X, y], columns=np.append(iris['feature_names'], 'target'))

ax2 = pd.plotting.scatter_matrix(df.iloc[:,:4], figsize=(11,11), c = y, marker='o', hist_kwds={'bins': 20}, s=60, alpha=.8)

plt.figure()
ax3 = pd.plotting.parallel_coordinates(df, 'target')
plt.show()

# %% [markdown]
# ## Definição do problema
#
# ### Caso 1
#
# Um rei estava interessado em realizar casamentos em massa em sua comunidade. Mas de 50.000 pessoas se beneficiariam (Suponha distribuição de homens e mulheres). O rei solicitou ao ministro do interior que fossem identificados todos os (25.000) potenciais pares para o casamento.
#
#
# #### problema
#
# * Como limitar o número de variáveis
#
# * Delimitar o escopo
#
# * Elaborar uma estrutura (para o DW por exemplo)
#
# Pode ser delimitado com casamento baseado em horóscopo.
#
# Nova definição:
#
# * Identificar todos os casamentos possiveis da população de 50.000 habitantes utilizando compatibilidade por horóscopo.
#
#
# ### Caso 2
#
# Uma companhia estava tendo boas vendas nos últimos anos. Em um ano eles observaram que as vendas começaram a cair a cada trimestre. O diretor da empresa queria saber como melhorar as vendas de modo a voltar à tendência de alta de receita anteriormente.
#
# #### problema
#
# Pode ser delimitado com alinhamento de variáveis. Por exemplo: redução das vendas está alinhada (corelacionada) com redução da produção, baixo estoque ?
#
# Nova definição:
#
# * Análise de disponibilidade de produtos nas lojas que está causando a queda nas vendas.
